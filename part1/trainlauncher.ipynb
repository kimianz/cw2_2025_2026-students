# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/cw2_2025_2026-students-main/cw2_2025_2026-students-main/part1
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/cw2_2025_2026-students-main/cw2_2025_2026-students-main/part1

# %%
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 5.2 MB/s eta 0:00:00
# ...

# %%
# !python train.py --model-config model_config.yaml --train-config train_config.yaml
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Load test source sentences from ../multi30k_data/test_2016_flickr.en
# Load test target sentences from ../multi30k_data/test_2016_flickr.fr
# Load vocab from vocab/vocab.json
# Load model from models/nmt_dropout_0.1.model
# Generating Predictions: 100% 1000/1000 [00:13<00:00, 75.83it/s]
# Corpus BLEU score = 53.66
# Saving predictions to test_outputs/nmt_dropout_0.1.json
